# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Importing data set from github

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv")
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8350.000000  8365.000000  8185.000000  4913.000000  4431.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.403596     6.136408    10.459379     5.044484     3.896235
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.200000    19.300000     0.000000     2.600000     4.750000
# 50%      13.300000    23.300000     0.000000     4.600000     8.700000
# 75%      17.400000    28.000000     1.000000     7.000000    10.700000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    7434.000000   8349.000000   8318.000000  8366.000000  8323.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        14.665721     10.174579      9.766986    16.833283    18.423774
# ...

# %% [markdown]
# using the describe function we can see some important things like the medium temperature in Australia (12c to 23c), we can also see that the temperature can reach very high levels.

# %% [markdown]
# # Data Analysis before processing data

# %%
sns.catplot(x='RainTomorrow', kind='count', data=df)

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     6195
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
plt.figure(figsize=(20,10))      
correlacao=sns.heatmap(df.corr(), square=True, annot=True)
correlacao.set_xticklabels(correlacao.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# verifying correlation between variables

# %%
sns.set(color_codes=True)
sns.distplot(df.MinTemp, kde=False)
# Out:
# C:\Users\welcome\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MinTemp'>

# %%
sns.set(color_codes=True)
sns.distplot(df.MaxTemp, kde=False)
# Out:
# <AxesSubplot:xlabel='MaxTemp'>

# %%
sns.relplot(x='MinTemp', y='MaxTemp', hue='RainTomorrow', data=df)

# %%
sns.relplot(x='Sunshine', y='MaxTemp',hue='RainTomorrow', data=df)

# %%
sns.catplot(x='RainTomorrow', y='MinTemp', kind='box', data=df)

# %% [markdown]
# checking the correlation of our RainTomorrow and MaxTemp variables we can see that we have a slight difference when we have higher temperatures

# %%
sns.catplot(x='RainTomorrow', y='MaxTemp', kind='box', data=df)

# %% [markdown]
# # Processing Data

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
df['MinTemp']=df['MinTemp'].fillna(df['MinTemp'].mean())
df['MaxTemp']=df['MaxTemp'].fillna(df['MaxTemp'].mean())
df['Rainfall']=df['Rainfall'].fillna(df['Rainfall'].mean())
df['Evaporation']=df['Evaporation'].fillna(df['Evaporation'].mean())
df['Sunshine']=df['Sunshine'].fillna(df['Sunshine'].mean())
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())
df['WindSpeed9am']=df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())
df['WindSpeed3pm']=df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean())
df['Humidity9am']=df['Humidity9am'].fillna(df['Humidity9am'].mean())
df['Humidity3pm']=df['Humidity3pm'].fillna(df['Humidity3pm'].mean())
df['Pressure9am']=df['Pressure9am'].fillna(df['Pressure9am'].mean())
df['Pressure3pm']=df['Pressure3pm'].fillna(df['Pressure3pm'].mean())
df['Cloud9am']=df['Cloud9am'].fillna(df['Cloud9am'].mean())
df['Cloud3pm']=df['Cloud3pm'].fillna(df['Cloud3pm'].mean())
df['Temp9am']=df['Temp9am'].fillna(df['Temp9am'].mean())
df['Temp3pm']=df['Temp3pm'].fillna(df['Temp3pm'].mean())

# %%
df['RainToday']=df['RainToday'].astype(str)
df['RainTomorrow']=df['RainTomorrow'].astype(str)
df['WindDir9am']=df['WindDir9am'].astype(str)
df['WindDir3pm']=df['WindDir3pm'].astype(str)
df['WindGustDir']=df['WindGustDir'].astype(str)

# %%
df['RainToday']=df['RainToday'].fillna(df['RainToday'].mean())
df['RainTomorrow']=df['RainTomorrow'].fillna(df['RainTomorrow'].mean())
df['WindDir9am']=df['WindDir9am'].fillna(df['WindDir9am'].mean())
df['WindDir3pm']=df['WindDir3pm'].fillna(df['WindDir3pm'].mean())
df['WindGustDir']=df['WindGustDir'].fillna(df['WindGustDir'].mean())

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# # Model Building

# %%
df=df.drop('Date',1)

# %%
x=df.iloc[:,0:21].values

# %%
y=df.iloc[:,-1].values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_Location=LabelEncoder()
label_encoder_WindGustDir=LabelEncoder()
label_encoder_WindGustSpeed=LabelEncoder()
label_encoder_WindDir9am=LabelEncoder()
label_encoder_WindDir3pm=LabelEncoder()
label_encoder_RainToday=LabelEncoder()

# %%
x[:,0]=label_encoder_Location.fit_transform(x[:,0])
x[:,6]=label_encoder_WindGustDir.fit_transform(x[:,6])
x[:,7]=label_encoder_WindGustSpeed.fit_transform(x[:,7])
x[:,8]=label_encoder_WindDir9am.fit_transform(x[:,8])
x[:,9]=label_encoder_WindDir3pmn.fit_transform(x[:,9])
x[:,20]=label_encoder_RainToday.fit_transform(x[:,20])

# %% [markdown]
# # StandardScaler

# %% [markdown]
# we will run the models before scaling the data, after we will run the StandardScaler and MinMax scaler and verify if we have best results by using this scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_standard=scaler.fit_transform(x)

# %%
x_standard[0]
# Out:
# array([-1.51577598e+00,  3.84250100e-02, -1.57008852e-01, -2.13985662e-01,
#         2.30589346e-16,  1.25747163e-15,  8.22266366e-01,  3.67958901e-01,
#         8.88498019e-01,  1.26624797e+00,  6.07461217e-01,  5.63297096e-01,
#         1.89438959e-01, -1.59740581e+00, -1.58400335e+00, -1.30866453e+00,
#         1.41345871e+00,  3.86285070e-16, -1.53712470e-01, -1.08138052e-01,
#        -5.70378719e-01])

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
obj_norm=MinMaxScaler().fit(x)

# %%
x_normalization=obj_norm.transform(x)

# %%
x_normalization[0]
# Out:
# array([0.09090909, 0.50491803, 0.39410188, 0.00161725, 0.03716824,
#        0.54907949, 0.8125    , 0.40384615, 0.8125    , 0.875     ,
#        0.31746032, 0.28915663, 0.67777778, 0.17204301, 0.36382114,
#        0.45574388, 1.        , 0.56289782, 0.4       , 0.39402174,
#        0.        ])

# %%
from sklearn.model_selection import train_test_split

# %%
x_treinamento, x_teste, y_treinamento,y_teste=train_test_split(x_normalization, y,test_size=0.3, random_state=0)

# %%
x_treinamento.shape,y_treinamento.shape
# Out:
# ((5897, 21), (5897,))

# %%
x_teste.shape, y_teste.shape
# Out:
# ((2528, 21), (2528,))

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# Running Gaussian Model

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_bayes=GaussianNB()
naive_bayes.fit(x_treinamento, y_treinamento)
# Out:
# GaussianNB()

# %%
previsoes=naive_bayes.predict(x_teste)

# %%
previsoes
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype='<U3')

# %%
from sklearn.metrics import confusion_matrix

# %%
confusao=confusion_matrix(y_teste,previsoes)

# %%
accuracy_score(y_teste, previsoes)
# Out:
# 0.7776898734177216

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.84      0.86      1855
#          Yes       0.55      0.61      0.58       593
#          nan       0.49      0.46      0.48        80
#
#     accuracy                           0.78      2528
#    macro avg       0.64      0.64      0.64      2528
# weighted avg       0.79      0.78      0.78      2528

# %%
score_naive_gaussian=0.7776898734177216

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.84      0.86      1855
#          Yes       0.55      0.61      0.58       593
#          nan       0.49      0.46      0.48        80
#
#     accuracy                           0.78      2528
#    macro avg       0.64      0.64      0.64      2528
# weighted avg       0.79      0.78      0.78      2528

# %% [markdown]
# Runnig BernoulliNB Model

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
naive_bayes=BernoulliNB()
naive_bayes.fit(x_treinamento, y_treinamento)
# Out:
# BernoulliNB()

# %%
previsoes=naive_bayes.predict(x_teste)

# %%
previsoes
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype='<U3')

# %%
accuracy_score(y_teste,previsoes)
# Out:
# 0.7278481012658228

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.83      0.83      1855
#          Yes       0.44      0.51      0.47       593
#          nan       0.00      0.00      0.00        80
#
#     accuracy                           0.73      2528
#    macro avg       0.43      0.45      0.44      2528
# weighted avg       0.72      0.73      0.72      2528

# %% [markdown]
# # DecisionTreeClassifier

# %%
arvore_entropy=DecisionTreeClassifier(criterion='entropy')

# %%
arvore_entropy.fit(x_treinamento,y_treinamento)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
previsoes=arvore_entropy.predict(x_teste)

# %%
accuracy_score(y_teste,previsoes)
# Out:
# 0.8200158227848101

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.88      0.88      1855
#          Yes       0.65      0.63      0.64       593
#          nan       0.65      0.78      0.71        80
#
#     accuracy                           0.82      2528
#    macro avg       0.73      0.76      0.74      2528
# weighted avg       0.82      0.82      0.82      2528

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest=RandomForestClassifier(n_estimators=100,criterion='entropy',random_state=0)
random_forest.fit(x_treinamento, y_treinamento)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
previsoes=random_forest.predict(x_teste)

# %%
previsoes
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
accuracy_score(y_teste,previsoes)
# Out:
# 0.8840981012658228

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.90      0.96      0.93      1855
#          Yes       0.83      0.67      0.74       593
#          nan       0.93      0.69      0.79        80
#
#     accuracy                           0.88      2528
#    macro avg       0.88      0.77      0.82      2528
# weighted avg       0.88      0.88      0.88      2528

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=27,metric='minkowski',p=2)

# %%
knn.fit(x_treinamento,y_treinamento)
# Out:
# KNeighborsClassifier(n_neighbors=27)

# %%
previsoes=knn.predict(x_teste)

# %%
previsoes
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
accuracy_score(y_teste,previsoes)
# Out:
# 0.8045886075949367

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.94      0.89      1855
#          Yes       0.68      0.51      0.58       593
#          nan       0.00      0.00      0.00        80
#
#     accuracy                           0.81      2528
#    macro avg       0.51      0.48      0.49      2528
# weighted avg       0.78      0.81      0.79      2528
# C:\Users\welcome\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\welcome\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
svm=SVC(kernel='linear', random_state=1)

# %%
svm.fit(x_treinamento,y_treinamento)
# Out:
# SVC(kernel='linear', random_state=1)

# %%
previsoes=svm.predict(x_teste)

# %%
previsoes
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
accuracy_score(y_teste,previsoes)
# Out:
# 0.8125

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.94      0.89      1855
#          Yes       0.68      0.51      0.58       593
#          nan       0.00      0.00      0.00        80
#
#     accuracy                           0.81      2528
#    macro avg       0.51      0.48      0.49      2528
# weighted avg       0.78      0.81      0.79      2528
# C:\Users\welcome\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\welcome\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic=LogisticRegression(random_state=1, solver='lbfgs',max_iter=1000)

# %%
logistic.fit(x_treinamento,y_treinamento)
# Out:
# LogisticRegression(max_iter=1000, random_state=1)

# %%
previsoes=logistic.predict(x_teste)

# %%
previsoes
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
accuracy_score(y_teste,previsoes)
# Out:
# 0.8097310126582279

# %%
print(classification_report(y_teste,previsoes))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.85      0.93      0.89      1855
#          Yes       0.66      0.52      0.58       593
#          nan       0.53      0.12      0.20        80
#
#     accuracy                           0.81      2528
#    macro avg       0.68      0.53      0.56      2528
# weighted avg       0.79      0.81      0.79      2528

# %% [markdown]
# # Checking Results

# %%
GaussianNB             - 0.7776898734177216
BernoulliNB            - 0.7278481012658228
DecisionTreeClassifier - 0.8200158227848101
RandomForestClassifier - 0.8840981012658228
KNeighborsClassifier   - 0.8045886075949367
SVC                    - 0.8125
LogisticRegression     - 0.8097310126582279
